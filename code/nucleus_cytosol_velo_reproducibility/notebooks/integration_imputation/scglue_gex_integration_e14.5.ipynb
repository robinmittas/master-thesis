# %% [markdown]
# # Integration of snRNA and scRNA data
#
# In this notebook snRNA and scRNA data is integrated into one latent space. To construct a common latent space for both measurements we are using `scglue` in this notebook
#
# **Requires:**
# - `/vol/storage/data/pancreas_multiome/processed/gex_e14.5.h5ad`
# - `/vol/storage/data/pancreas_sc/processed/gex_e14.5.h5ad`
# - `/vol/storage/data/gencode.vM25.chr_patch_hapl_scaff.annotation.gtf.gz` (downloadable from ftp://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_mouse/release_M25/gencode.vM25.chr_patch_hapl_scaff.annotation.gtf.gz)
#
# **Output:**
# - `/vol/storage/data/pancreas_sc_multiome/sn_sc_rna_scglue.h5ad`

# %% [markdown]
# ## Library imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from itertools import chain

import mplscience
import scglue

from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt
import seaborn as sns

import anndata as ad
import scanpy as sc
import scvelo as scv

sys.path.append("../..")
from paths import FIG_DIR, DATA_DIR, PROJECT_DIR  # isort: skip  # noqa: E402

# %% [markdown]
# ## General settings

# %%
SAVE_FIGURES = True
SAVE_MODEL = True
SN_PROCESSED_DIR = PROJECT_DIR / "pancreas_multiome" / "processed"
SC_PROCESSED_DIR = PROJECT_DIR / "pancreas_sc" / "processed"

sns.reset_defaults()
sns.reset_orig()
scv.settings.set_figure_params("scvelo", dpi_save=400, dpi=80, transparent=True, fontsize=20, color_map="viridis")

celltype_colors = {
    "celltype_colors": {
        "Alpha": "#1f78b4",
        "Beta": "#b2df8a",
        "Delta": "#6a3d9a",
        "Ductal": "#8fbc8f",
        "Epsilon": "#cab2d6",
        "Ngn3 high EP": "#fdbf6f",
        "Ngn3 low EP": "#f4a460",
        "Pre-endocrine": "#ff7f00",
    },
    "celltype_fine_colors": {
        "Alpha": "#1f78b4",
        "Beta": "#b2df8a",
        "Delta": "#6a3d9a",
        "Ductal": "#8fbc8f",
        "Eps/Delta progenitors": "#029e73",
        "Epsilon": "#cab2d6",
        "Ngn3 high EP": "#fdbf6f",
        "Ngn3 low EP": "#f4a460",
        "Fev+ Alpha": "#d55e00",
        "Fev+ Beta": "#cc78bc",
        "Fev+ Delta": "#ca9161",
    },
}

# %% [markdown]
# ## Read Data

# %%
adata_sn = sc.read(SN_PROCESSED_DIR / "gex_e14.5.h5ad")
adata_sc = sc.read(SC_PROCESSED_DIR / "gex_e14.5.h5ad")

# %% [markdown]
# ## Preprocess scRNA-seq data
# Similarly to https://scglue.readthedocs.io/en/latest/preprocessing.html#Construct-prior-regulatory-graph

# %%
adata_sc.layers["counts"] = adata_sc.layers["spliced"] + adata_sc.layers["unspliced"]
adata_sc.X = adata_sc.layers["counts"]
scv.pp.filter_genes_dispersion(adata_sc)
sc.pp.normalize_total(adata_sc)
sc.pp.log1p(adata_sc)
sc.pp.scale(adata_sc)
sc.tl.pca(adata_sc, n_comps=100, svd_solver="auto")
sc.pp.neighbors(adata_sc, metric="cosine")
sc.tl.umap(adata_sc)

adata_sc.uns["celltype_colors"] = celltype_colors["celltype_colors"]
scv.pl.umap(adata_sc, color="celltype")
# Out:
# Extracted 2058 highly variable genes.

# %% [markdown]
# ## Preprocess snRNA data
# Similarly to https://scglue.readthedocs.io/en/latest/preprocessing.html#Construct-prior-regulatory-graph

# %%
adata_sn.layers["counts"] = adata_sn.layers["spliced"] + adata_sn.layers["unspliced"]
adata_sn.X = adata_sn.layers["counts"]
scv.pp.filter_genes_dispersion(adata_sn)
sc.pp.normalize_total(adata_sn)
sc.pp.log1p(adata_sn)
sc.pp.scale(adata_sn)
sc.tl.pca(adata_sn, n_comps=100, svd_solver="auto")
sc.pp.neighbors(adata_sn, metric="cosine")
sc.tl.umap(adata_sn)

adata_sn.uns["celltype_colors"] = celltype_colors["celltype_colors"]
scv.pl.umap(adata_sn, color="celltype")
# Out:
# Extracted 2010 highly variable genes.

# %% [markdown]
# ## Construct guidance graph for GLUE

# %%
# Add chromsone, start, end information to sc data with scglue
scglue.data.get_gene_annotation(
    adata_sc, gtf=PROJECT_DIR / "gencode.vM25.chr_patch_hapl_scaff.annotation.gtf.gz", gtf_by="gene_name"
)

scglue.data.get_gene_annotation(
    adata_sn, gtf=PROJECT_DIR / "gencode.vM25.chr_patch_hapl_scaff.annotation.gtf.gz", gtf_by="gene_name"
)

guidance = scglue.genomics.rna_anchored_guidance_graph(adata_sc, adata_sn)

# Run function to check graph
scglue.graph.check_graph(guidance, [adata_sc, adata_sn])
# Out:
# window_graph:   0%|          | 0/2058 [00:00<?, ?it/s]
# [INFO] check_graph: Checking variable coverage...
# [INFO] check_graph: Checking edge attributes...
# [INFO] check_graph: Checking self-loops...
# [INFO] check_graph: Checking graph symmetry...
# [INFO] check_graph: All checks passed!

# %% [markdown]
# ## Configure data for scglue model training

# %%
scglue.models.configure_dataset(adata_sc, "NB", use_highly_variable=True, use_layer="counts", use_rep="X_pca")
scglue.models.configure_dataset(adata_sn, "NB", use_highly_variable=True, use_layer="counts", use_rep="X_pca")

guidance_hvf = guidance.subgraph(
    chain(adata_sc.var.query("highly_variable").index, adata_sn.var.query("highly_variable").index)
).copy()

# %% [markdown]
# ## Train GLUE model

# %%
glue = scglue.models.fit_SCGLUE(
    {"sc_rna": adata_sc, "sn_rna": adata_sn}, guidance_hvf, fit_kws={"directory": DATA_DIR / "glue_gex"}
)
# Out:
# [INFO] fit_SCGLUE: Pretraining SCGLUE model...
# [INFO] autodevice: Using GPU 0 as computation device.
# [INFO] check_graph: Checking variable coverage...
# [INFO] check_graph: Checking edge attributes...
# [INFO] check_graph: Checking self-loops...
# [INFO] check_graph: Checking graph symmetry...
# [INFO] SCGLUEModel: Setting `graph_batch_size` = 1769
# [INFO] SCGLUEModel: Setting `max_epochs` = 260
# [INFO] SCGLUEModel: Setting `patience` = 22
# [INFO] SCGLUEModel: Setting `reduce_lr_patience` = 11
# [INFO] SCGLUETrainer: Using training directory: "/vol/storage/robin/code/nucleus_cytosol_velo_reproducibility_integration/data/glue_gex/pretrain"
# [INFO] SCGLUETrainer: [Epoch 10] train={'g_nll': 0.283, 'g_kl': 0.091, 'g_elbo': 0.374, 'x_sc_rna_nll': 0.631, 'x_sc_rna_kl': 0.012, 'x_sc_rna_elbo': 0.643, 'x_sn_rna_nll': 0.619, 'x_sn_rna_kl': 0.014, 'x_sn_rna_elbo': 0.632, 'dsc_loss': 0.686, 'vae_loss': 1.291, 'gen_loss': 1.256}, val={'g_nll': 0.22, 'g_kl': 0.093, 'g_elbo': 0.313, 'x_sc_rna_nll': 0.634, 'x_sc_rna_kl': 0.011, 'x_sc_rna_elbo': 0.645, 'x_sn_rna_nll': 0.619, 'x_sn_rna_kl': 0.013, 'x_sn_rna_elbo': 0.633, 'dsc_loss': 0.693, 'vae_loss': 1.29, 'gen_loss': 1.255}, 4.1s elapsed
# [INFO] SCGLUETrainer: [Epoch 20] train={'g_nll': 0.09, 'g_kl': 0.096, 'g_elbo': 0.186, 'x_sc_rna_nll': 0.618, 'x_sc_rna_kl': 0.012, 'x_sc_rna_elbo': 0.63, 'x_sn_rna_nll': 0.608, 'x_sn_rna_kl': 0.014, 'x_sn_rna_elbo': 0.622, 'dsc_loss': 0.687, 'vae_loss': 1.259, 'gen_loss': 1.225}, val={'g_nll': 0.087, 'g_kl': 0.096, 'g_elbo': 0.183, 'x_sc_rna_nll': 0.615, 'x_sc_rna_kl': 0.012, 'x_sc_rna_elbo': 0.626, 'x_sn_rna_nll': 0.613, 'x_sn_rna_kl': 0.014, 'x_sn_rna_elbo': 0.627, 'dsc_loss': 0.687, 'vae_loss': 1.261, 'gen_loss': 1.226}, 4.7s elapsed
# [INFO] SCGLUETrainer: [Epoch 30] train={'g_nll': 0.082, 'g_kl': 0.096, 'g_elbo': 0.178, 'x_sc_rna_nll': 0.615, 'x_sc_rna_kl': 0.012, 'x_sc_rna_elbo': 0.627, 'x_sn_rna_nll': 0.605, 'x_sn_rna_kl': 0.014, 'x_sn_rna_elbo': 0.619, 'dsc_loss': 0.687, 'vae_loss': 1.253, 'gen_loss': 1.219}, val={'g_nll': 0.079, 'g_kl': 0.097, 'g_elbo': 0.176, 'x_sc_rna_nll': 0.613, 'x_sc_rna_kl': 0.011, 'x_sc_rna_elbo': 0.625, 'x_sn_rna_nll': 0.611, 'x_sn_rna_kl': 0.014, 'x_sn_rna_elbo': 0.625, 'dsc_loss': 0.691, 'vae_loss': 1.257, 'gen_loss': 1.222}, 4.8s elapsed
# Epoch 00033: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 00033: reducing learning rate of group 0 to 2.0000e-04.
# [INFO] LRScheduler: Learning rate reduction: step 1
# [INFO] SCGLUETrainer: [Epoch 40] train={'g_nll': 0.079, 'g_kl': 0.097, 'g_elbo': 0.176, 'x_sc_rna_nll': 0.612, 'x_sc_rna_kl': 0.012, 'x_sc_rna_elbo': 0.624, 'x_sn_rna_nll': 0.604, 'x_sn_rna_kl': 0.014, 'x_sn_rna_elbo': 0.618, 'dsc_loss': 0.686, 'vae_loss': 1.249, 'gen_loss': 1.215}, val={'g_nll': 0.076, 'g_kl': 0.097, 'g_elbo': 0.173, 'x_sc_rna_nll': 0.61, 'x_sc_rna_kl': 0.012, 'x_sc_rna_elbo': 0.622, 'x_sn_rna_nll': 0.613, 'x_sn_rna_kl': 0.014, 'x_sn_rna_elbo': 0.627, 'dsc_loss': 0.689, 'vae_loss': 1.256, 'gen_loss': 1.221}, 3.8s elapsed
# [INFO] SCGLUETrainer: [Epoch 50] train={'g_nll': 0.082, 'g_kl': 0.098, 'g_elbo': 0.179, 'x_sc_rna_nll': 0.612, 'x_sc_rna_kl': 0.012, 'x_sc_rna_elbo': 0.624, 'x_sn_rna_nll': 0.604, 'x_sn_rna_kl': 0.014, 'x_sn_rna_elbo': 0.618, 'dsc_loss': 0.689, 'vae_loss': 1.249, 'gen_loss': 1.215}, val={'g_nll': 0.078, 'g_kl': 0.098, 'g_elbo': 0.175, 'x_sc_rna_nll': 0.61, 'x_sc_rna_kl': 0.012, 'x_sc_rna_elbo': 0.622, 'x_sn_rna_nll': 0.61, 'x_sn_rna_kl': 0.014, 'x_sn_rna_elbo': 0.624, 'dsc_loss': 0.686, 'vae_loss': 1.253, 'gen_loss': 1.219}, 4.4s elapsed
# Epoch 00059: reducing learning rate of group 0 to 2.0000e-05.
# Epoch 00059: reducing learning rate of group 0 to 2.0000e-05.
# [INFO] LRScheduler: Learning rate reduction: step 2
# [INFO] SCGLUETrainer: [Epoch 60] train={'g_nll': 0.078, 'g_kl': 0.098, 'g_elbo': 0.176, 'x_sc_rna_nll': 0.613, 'x_sc_rna_kl': 0.012, 'x_sc_rna_elbo': 0.624, 'x_sn_rna_nll': 0.604, 'x_sn_rna_kl': 0.014, 'x_sn_rna_elbo': 0.618, 'dsc_loss': 0.688, 'vae_loss': 1.249, 'gen_loss': 1.215}, val={'g_nll': 0.079, 'g_kl': 0.098, 'g_elbo': 0.177, 'x_sc_rna_nll': 0.612, 'x_sc_rna_kl': 0.012, 'x_sc_rna_elbo': 0.624, 'x_sn_rna_nll': 0.607, 'x_sn_rna_kl': 0.014, 'x_sn_rna_elbo': 0.621, 'dsc_loss': 0.686, 'vae_loss': 1.252, 'gen_loss': 1.217}, 3.7s elapsed
# 2023-09-23 13:34:55,259 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# [INFO] EarlyStopping: Restoring checkpoint "57"...
# [INFO] EarlyStopping: Restoring checkpoint "57"...
# [INFO] fit_SCGLUE: Estimating balancing weight...
# [INFO] estimate_balancing_weight: Clustering cells...
# [INFO] estimate_balancing_weight: Matching clusters...
# [INFO] estimate_balancing_weight: Matching array shape = (16, 17)...
# [INFO] estimate_balancing_weight: Estimating balancing weight...
# [INFO] fit_SCGLUE: Fine-tuning SCGLUE model...
# [INFO] check_graph: Checking variable coverage...
# [INFO] check_graph: Checking edge attributes...
# [INFO] check_graph: Checking self-loops...
# [INFO] check_graph: Checking graph symmetry...
# [INFO] SCGLUEModel: Setting `graph_batch_size` = 1769
# [INFO] SCGLUEModel: Setting `align_burnin` = 44
# [INFO] SCGLUEModel: Setting `max_epochs` = 260
# [INFO] SCGLUEModel: Setting `patience` = 22
# [INFO] SCGLUEModel: Setting `reduce_lr_patience` = 11
# [INFO] SCGLUETrainer: Using training directory: "/vol/storage/robin/code/nucleus_cytosol_velo_reproducibility_integration/data/glue_gex/fine-tune"
# [INFO] SCGLUETrainer: [Epoch 10] train={'g_nll': 0.079, 'g_kl': 0.097, 'g_elbo': 0.176, 'x_sc_rna_nll': 0.614, 'x_sc_rna_kl': 0.012, 'x_sc_rna_elbo': 0.626, 'x_sn_rna_nll': 0.607, 'x_sn_rna_kl': 0.014, 'x_sn_rna_elbo': 0.621, 'dsc_loss': 0.689, 'vae_loss': 1.254, 'gen_loss': 1.219}, val={'g_nll': 0.076, 'g_kl': 0.097, 'g_elbo': 0.173, 'x_sc_rna_nll': 0.615, 'x_sc_rna_kl': 0.012, 'x_sc_rna_elbo': 0.626, 'x_sn_rna_nll': 0.603, 'x_sn_rna_kl': 0.013, 'x_sn_rna_elbo': 0.616, 'dsc_loss': 0.692, 'vae_loss': 1.25, 'gen_loss': 1.215}, 3.7s elapsed
# [INFO] SCGLUETrainer: [Epoch 20] train={'g_nll': 0.079, 'g_kl': 0.097, 'g_elbo': 0.176, 'x_sc_rna_nll': 0.613, 'x_sc_rna_kl': 0.012, 'x_sc_rna_elbo': 0.625, 'x_sn_rna_nll': 0.607, 'x_sn_rna_kl': 0.013, 'x_sn_rna_elbo': 0.62, 'dsc_loss': 0.682, 'vae_loss': 1.252, 'gen_loss': 1.218}, val={'g_nll': 0.075, 'g_kl': 0.097, 'g_elbo': 0.172, 'x_sc_rna_nll': 0.614, 'x_sc_rna_kl': 0.012, 'x_sc_rna_elbo': 0.625, 'x_sn_rna_nll': 0.601, 'x_sn_rna_kl': 0.013, 'x_sn_rna_elbo': 0.614, 'dsc_loss': 0.719, 'vae_loss': 1.247, 'gen_loss': 1.211}, 3.8s elapsed
# [INFO] SCGLUETrainer: [Epoch 30] train={'g_nll': 0.077, 'g_kl': 0.097, 'g_elbo': 0.174, 'x_sc_rna_nll': 0.614, 'x_sc_rna_kl': 0.012, 'x_sc_rna_elbo': 0.625, 'x_sn_rna_nll': 0.606, 'x_sn_rna_kl': 0.013, 'x_sn_rna_elbo': 0.619, 'dsc_loss': 0.687, 'vae_loss': 1.251, 'gen_loss': 1.217}, val={'g_nll': 0.073, 'g_kl': 0.097, 'g_elbo': 0.17, 'x_sc_rna_nll': 0.614, 'x_sc_rna_kl': 0.011, 'x_sc_rna_elbo': 0.625, 'x_sn_rna_nll': 0.604, 'x_sn_rna_kl': 0.013, 'x_sn_rna_elbo': 0.617, 'dsc_loss': 0.693, 'vae_loss': 1.249, 'gen_loss': 1.215}, 4.7s elapsed
# [INFO] SCGLUETrainer: [Epoch 40] train={'g_nll': 0.074, 'g_kl': 0.097, 'g_elbo': 0.171, 'x_sc_rna_nll': 0.613, 'x_sc_rna_kl': 0.012, 'x_sc_rna_elbo': 0.625, 'x_sn_rna_nll': 0.606, 'x_sn_rna_kl': 0.013, 'x_sn_rna_elbo': 0.62, 'dsc_loss': 0.68, 'vae_loss': 1.251, 'gen_loss': 1.217}, val={'g_nll': 0.083, 'g_kl': 0.097, 'g_elbo': 0.179, 'x_sc_rna_nll': 0.609, 'x_sc_rna_kl': 0.012, 'x_sc_rna_elbo': 0.621, 'x_sn_rna_nll': 0.604, 'x_sn_rna_kl': 0.013, 'x_sn_rna_elbo': 0.618, 'dsc_loss': 0.679, 'vae_loss': 1.246, 'gen_loss': 1.212}, 4.1s elapsed
# [INFO] SCGLUETrainer: [Epoch 50] train={'g_nll': 0.079, 'g_kl': 0.097, 'g_elbo': 0.176, 'x_sc_rna_nll': 0.613, 'x_sc_rna_kl': 0.012, 'x_sc_rna_elbo': 0.625, 'x_sn_rna_nll': 0.606, 'x_sn_rna_kl': 0.013, 'x_sn_rna_elbo': 0.619, 'dsc_loss': 0.678, 'vae_loss': 1.251, 'gen_loss': 1.217}, val={'g_nll': 0.079, 'g_kl': 0.097, 'g_elbo': 0.175, 'x_sc_rna_nll': 0.611, 'x_sc_rna_kl': 0.011, 'x_sc_rna_elbo': 0.622, 'x_sn_rna_nll': 0.603, 'x_sn_rna_kl': 0.013, 'x_sn_rna_elbo': 0.616, 'dsc_loss': 0.69, 'vae_loss': 1.245, 'gen_loss': 1.21}, 4.0s elapsed
# [INFO] SCGLUETrainer: [Epoch 60] train={'g_nll': 0.078, 'g_kl': 0.097, 'g_elbo': 0.175, 'x_sc_rna_nll': 0.613, 'x_sc_rna_kl': 0.012, 'x_sc_rna_elbo': 0.625, 'x_sn_rna_nll': 0.605, 'x_sn_rna_kl': 0.013, 'x_sn_rna_elbo': 0.618, 'dsc_loss': 0.68, 'vae_loss': 1.249, 'gen_loss': 1.215}, val={'g_nll': 0.075, 'g_kl': 0.097, 'g_elbo': 0.172, 'x_sc_rna_nll': 0.611, 'x_sc_rna_kl': 0.011, 'x_sc_rna_elbo': 0.622, 'x_sn_rna_nll': 0.604, 'x_sn_rna_kl': 0.013, 'x_sn_rna_elbo': 0.617, 'dsc_loss': 0.722, 'vae_loss': 1.246, 'gen_loss': 1.21}, 4.0s elapsed
# Epoch 00069: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 00069: reducing learning rate of group 0 to 2.0000e-04.
# [INFO] LRScheduler: Learning rate reduction: step 1
# [INFO] SCGLUETrainer: [Epoch 70] train={'g_nll': 0.076, 'g_kl': 0.097, 'g_elbo': 0.173, 'x_sc_rna_nll': 0.61, 'x_sc_rna_kl': 0.011, 'x_sc_rna_elbo': 0.621, 'x_sn_rna_nll': 0.604, 'x_sn_rna_kl': 0.013, 'x_sn_rna_elbo': 0.617, 'dsc_loss': 0.687, 'vae_loss': 1.246, 'gen_loss': 1.211}, val={'g_nll': 0.072, 'g_kl': 0.097, 'g_elbo': 0.169, 'x_sc_rna_nll': 0.608, 'x_sc_rna_kl': 0.011, 'x_sc_rna_elbo': 0.62, 'x_sn_rna_nll': 0.605, 'x_sn_rna_kl': 0.013, 'x_sn_rna_elbo': 0.618, 'dsc_loss': 0.708, 'vae_loss': 1.244, 'gen_loss': 1.209}, 4.3s elapsed
# [INFO] SCGLUETrainer: [Epoch 80] train={'g_nll': 0.075, 'g_kl': 0.097, 'g_elbo': 0.172, 'x_sc_rna_nll': 0.611, 'x_sc_rna_kl': 0.011, 'x_sc_rna_elbo': 0.622, 'x_sn_rna_nll': 0.606, 'x_sn_rna_kl': 0.013, 'x_sn_rna_elbo': 0.619, 'dsc_loss': 0.688, 'vae_loss': 1.248, 'gen_loss': 1.213}, val={'g_nll': 0.072, 'g_kl': 0.097, 'g_elbo': 0.169, 'x_sc_rna_nll': 0.61, 'x_sc_rna_kl': 0.011, 'x_sc_rna_elbo': 0.621, 'x_sn_rna_nll': 0.602, 'x_sn_rna_kl': 0.013, 'x_sn_rna_elbo': 0.615, 'dsc_loss': 0.701, 'vae_loss': 1.243, 'gen_loss': 1.208}, 4.8s elapsed
# Epoch 00081: reducing learning rate of group 0 to 2.0000e-05.
# Epoch 00081: reducing learning rate of group 0 to 2.0000e-05.
# [INFO] LRScheduler: Learning rate reduction: step 2
# [INFO] SCGLUETrainer: [Epoch 90] train={'g_nll': 0.077, 'g_kl': 0.097, 'g_elbo': 0.174, 'x_sc_rna_nll': 0.61, 'x_sc_rna_kl': 0.011, 'x_sc_rna_elbo': 0.621, 'x_sn_rna_nll': 0.604, 'x_sn_rna_kl': 0.013, 'x_sn_rna_elbo': 0.617, 'dsc_loss': 0.68, 'vae_loss': 1.245, 'gen_loss': 1.211}, val={'g_nll': 0.077, 'g_kl': 0.097, 'g_elbo': 0.174, 'x_sc_rna_nll': 0.609, 'x_sc_rna_kl': 0.011, 'x_sc_rna_elbo': 0.62, 'x_sn_rna_nll': 0.602, 'x_sn_rna_kl': 0.013, 'x_sn_rna_elbo': 0.615, 'dsc_loss': 0.695, 'vae_loss': 1.243, 'gen_loss': 1.208}, 4.5s elapsed
# Epoch 00097: reducing learning rate of group 0 to 2.0000e-06.
# Epoch 00097: reducing learning rate of group 0 to 2.0000e-06.
# [INFO] LRScheduler: Learning rate reduction: step 3
# [INFO] SCGLUETrainer: [Epoch 100] train={'g_nll': 0.073, 'g_kl': 0.097, 'g_elbo': 0.17, 'x_sc_rna_nll': 0.61, 'x_sc_rna_kl': 0.011, 'x_sc_rna_elbo': 0.621, 'x_sn_rna_nll': 0.604, 'x_sn_rna_kl': 0.013, 'x_sn_rna_elbo': 0.618, 'dsc_loss': 0.686, 'vae_loss': 1.245, 'gen_loss': 1.211}, val={'g_nll': 0.072, 'g_kl': 0.097, 'g_elbo': 0.169, 'x_sc_rna_nll': 0.611, 'x_sc_rna_kl': 0.011, 'x_sc_rna_elbo': 0.623, 'x_sn_rna_nll': 0.601, 'x_sn_rna_kl': 0.013, 'x_sn_rna_elbo': 0.614, 'dsc_loss': 0.669, 'vae_loss': 1.243, 'gen_loss': 1.21}, 4.8s elapsed
# 2023-09-23 13:42:59,568 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# [INFO] EarlyStopping: Restoring checkpoint "106"...
# [INFO] EarlyStopping: Restoring checkpoint "106"...

# %% [markdown]
# ## Save model
# Can be loaded with `glue = scglue.models.load_model("glue_atac.dill")`

# %%
if SAVE_MODEL:
    glue.save(DATA_DIR / "glue_rna.dill")

# %% [markdown]
# ## Check integration diagnostics

# %%
# For the plot we need a column of dtype category, and to concat/ run integration_consistency, chrom needs to have same dtypes
adata_sc.var["chrom"] = adata_sc.var["chrom"].astype("category")
adata_sn.var["chrom"] = adata_sn.var["chrom"].astype("category")

# %%
# consistency score can just be calculated on genes which are just present in one of the modalities
common_var_names = set(adata_sc.var_names).intersection(adata_sn.var_names)
no_common_sc = set(adata_sc.var_names) - common_var_names
no_common_sn = set(adata_sn.var_names) - common_var_names

# %%
dx = scglue.models.integration_consistency(
    glue, {"sc_rna": adata_sc[:, list(no_common_sc)], "sn_rna": adata_sn[:, list(no_common_sn)]}, guidance_hvf
)
dx
# Out:
# [INFO] integration_consistency: Using layer "counts" for modality "sc_rna"
# [INFO] integration_consistency: Using layer "counts" for modality "sn_rna"
# [INFO] integration_consistency: Selecting aggregation "sum" for modality "sc_rna"
# [INFO] integration_consistency: Selecting aggregation "sum" for modality "sn_rna"
# [INFO] integration_consistency: Selecting log-norm preprocessing for modality "sc_rna"
# [INFO] integration_consistency: Selecting log-norm preprocessing for modality "sn_rna"
# [INFO] get_metacells: Clustering metacells...
# [WARNING] get_metacells: `faiss` is not installed, using `sklearn` instead... This might be slow with a large number of cells. Consider installing `faiss` following the guide from https://github.com/facebookresearch/faiss/blob/main/INSTALL.md
# [INFO] get_metacells: Aggregating metacells...
# [INFO] metacell_corr: Computing correlation on 10 common metacells...
# [INFO] get_metacells: Clustering metacells...
# [WARNING] get_metacells: `faiss` is not installed, using `sklearn` instead... This might be slow with a large number of cells. Consider installing `faiss` following the guide from https://github.com/facebookresearch/faiss/blob/main/INSTALL.md
# [INFO] get_metacells: Aggregating metacells...
# [INFO] metacell_corr: Computing correlation on 20 common metacells...
# [INFO] get_metacells: Clustering metacells...
# [WARNING] get_metacells: `faiss` is not installed, using `sklearn` instead... This might be slow with a large number of cells. Consider installing `faiss` following the guide from https://github.com/facebookresearch/faiss/blob/main/INSTALL.md
# [INFO] get_metacells: Aggregating metacells...
# [INFO] metacell_corr: Computing correlation on 50 common metacells...
# [INFO] get_metacells: Clustering metacells...
# [WARNING] get_metacells: `faiss` is not installed, using `sklearn` instead... This might be slow with a large number of cells. Consider installing `faiss` following the guide from https://github.com/facebookresearch/faiss/blob/main/INSTALL.md
# [INFO] get_metacells: Aggregating metacells...
# [INFO] metacell_corr: Computing correlation on 100 common metacells...
# [INFO] get_metacells: Clustering metacells...
# [WARNING] get_metacells: `faiss` is not installed, using `sklearn` instead... This might be slow with a large number of cells. Consider installing `faiss` following the guide from https://github.com/facebookresearch/faiss/blob/main/INSTALL.md
# [INFO] get_metacells: Aggregating metacells...
# [INFO] metacell_corr: Computing correlation on 199 common metacells...
#    n_meta  consistency
# 0      10     0.620006
# 1      20     0.602986
# 2      50     0.600357
# 3     100     0.591051
# 4     200     0.578891

# %%
with mplscience.style_context():
    sns.set_style(style="whitegrid")
    fig, ax = plt.subplots(figsize=(6, 4))
    sns.lineplot(x="n_meta", y="consistency", data=dx, color="silver").axhline(y=0.05, c="black", ls="--")
    if SAVE_FIGURES:
        path = FIG_DIR / "integration"
        path.mkdir(parents=True, exist_ok=True)
        fig.savefig(path / "consistency_score_gex.svg", format="svg", transparent=True, bbox_inches="tight")

# %% [markdown]
# ## Get latent representation

# %%
adata_sc.obsm["X_glue_gex"] = glue.encode_data("sc_rna", adata_sc)
adata_sn.obsm["X_glue_gex"] = glue.encode_data("sn_rna", adata_sn)

# %% [markdown]
# ## Plot UMAP of common latent space representation

# %%
combined = ad.concat([adata_sc, adata_sn])
sc.pp.neighbors(combined, use_rep="X_glue_gex", metric="cosine")
sc.tl.umap(combined)

combined.uns["celltype_colors"] = celltype_colors["celltype_colors"]
scv.pl.umap(combined, color=["celltype", "protocol"], ncols=1)

# %% [markdown]
# ## Estimate abundances

# %%
adata_sn = sc.read(SN_PROCESSED_DIR / "gex_e14.5.h5ad")
adata_sc = sc.read(SC_PROCESSED_DIR / "gex_e14.5.h5ad")

adata = ad.concat([adata_sc, adata_sn])

# first filter highly variable genes with scanpy where we can specify a batch_key
adata.layers["counts"] = adata.layers["spliced"] + adata.layers["unspliced"]
scv.pp.filter_genes(adata, min_counts=20)
sc.pp.highly_variable_genes(
    adata,
    flavor="seurat_v3",
    n_top_genes=2000,
    layer="counts",
    batch_key="protocol",
    subset=True,
)
# Out:
# AnnData object with n_obs × n_vars = 13146 × 13255
#     obs: 'day', 'celltype', 'n_counts', 'celltype_fine', 'protocol'
#     layers: 'spliced', 'unspliced'

# %%
# Get neighbor graph
adata.obsm["X_glue_gex"] = combined[adata.obs_names, :].obsm["X_glue_gex"]
sc.pp.neighbors(adata, use_rep="X_glue_gex", metric="cosine")
scv.tl.umap(adata)

# %%
# adata object still has raw counts, no need to reload
adata = scv.pp.estimate_abundance(
    adata,
    layers=["unspliced", "spliced"],
    mode="connectivities",
    dataset_key="protocol",
    sc_rna_name="scRNA-seq",
    min_estimation_samples=1,
    smooth_obs=False,  # dont smooth because moments basically do the same afterwards
    clip_cyto=True,
    lambda_correction=True,
    filter_zero_genes=True,
)
# Out:
# After running fixed-point iteration, `13139/13146` observations remain
# Removing `4.9723%` elements below 0

# %% [markdown]
# ## Calculate Moments and Min-max scale

# %%
scv.pp.normalize_per_cell(
    adata,
    layers=["unspliced_nucleus", "spliced_nucleus", "spliced_cytoplasm", "spliced_cell"],
)

scv.pp.moments(
    adata,
    use_rep="X_glue_gex",
    layers={"unspliced_nucleus": "Mu_nuc", "spliced_nucleus": "Ms_nuc", "spliced_cytoplasm": "Ms_cyt"},
)

scaler = MinMaxScaler()
adata.layers["Mu_nuc"] = scaler.fit_transform(adata.layers["Mu_nuc"])

scaler = MinMaxScaler()
adata.layers["Ms_nuc"] = scaler.fit_transform(adata.layers["Ms_nuc"])

scaler = MinMaxScaler()
adata.layers["Ms_cyt"] = scaler.fit_transform(adata.layers["Ms_cyt"])
# Out:
# Filtered out 266 genes that are detected 20 counts (spliced).
# Normalized count data: X, unspliced_nucleus, spliced_nucleus, spliced_cytoplasm, spliced_cell.
# Extracted 2000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:09) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:04) --> added
#     ['Mu_nuc', 'Ms_nuc', 'Ms_cyt'] moments of un/spliced abundances (adata.layers)

# %%
# Plot first 3 genes phase portraits to check if they look reasonable
for gene in range(3):
    plt.scatter(adata.layers["Ms_nuc"][:, gene], adata.layers["Ms_cyt"][:, gene], color="silver")
    plt.show()
    plt.scatter(adata.layers["Mu_nuc"][:, gene], adata.layers["Ms_nuc"][:, gene], color="silver")
    plt.show()

# %% [markdown]
# ## Store result with latent representation

# %%
adata.write(PROJECT_DIR / "pancreas_sc_multiome" / "sn_sc_rna_scglue.h5ad")
